# %%
# !gdal_merge.py \
    -v ../data/raw/rainier_lidar_datasets_dispersed/rainier_west_2002/dtm/*.tif \
    -o ../data/processed/rainier_lidar_datasets_dispersed/merged/dtm_2002.tif 

# !gdal_merge.py \
    -v ../data/raw/rainier_lidar_datasets_dispersed/rainier_2007/dtm/*.tif \
    -o ../data/processed/rainier_lidar_datasets_dispersed/merged/dtm_2007.tif

# !gdal_merge.py \
    -v ../data/raw/rainier_lidar_datasets_dispersed/lewis_2009/dtm/*.tif \
    -o ../data/processed/rainier_lidar_datasets_dispersed/merged/dtm_2009.tif

# !gdal_merge.py \
    -v ../data/raw/rainier_lidar_datasets_dispersed/pierce_2011/dtm/*.tif \
    -o ../data/processed/rainier_lidar_datasets_dispersed/merged/dtm_2011.tif

# !gdal_merge.py \
    -v ../data/raw/rainier_lidar_datasets_dispersed/rainier_2012/dtm/*.tif \
    -o ../data/processed/rainier_lidar_datasets_dispersed/merged/dtm_2012.tif

# !gdal_merge.py \
    -v ../data/raw/wa_state_lidar_datasets/*.dem \
    -o ../data/processed/wa_state_lidar_datasets/merged/dtm.tif
# Out:
# Processing file     1 of     4,  0.000% completed in 0 minutes.
# Filename: ../data/raw/rainier_lidar_datasets_dispersed/rainier_west_2002/dtm/rainier_west_2002_dtm_3.tif
# File Size: 461x7611x1
# Pixel Size: 6.000000 x -6.000000
# UL:(1295444.000000,565156.000000)   LR:(1298210.000000,519490.000000)
# Copy 0,0,461,7611 to 5222,7691,461,7611.
#
# Processing file     2 of     4, 25.000% completed in 0 minutes.
# Filename: ../data/raw/rainier_lidar_datasets_dispersed/rainier_west_2002/dtm/rainier_west_2002_dtm_4.tif
# File Size: 5360x7698x1
# Pixel Size: 6.000000 x -6.000000
# UL:(1264112.000000,565726.000000)   LR:(1296272.000000,519538.000000)
# Copy 0,0,5360,7698 to 0,7596,5360,7698.
#
# Processing file     3 of     4, 50.000% completed in 0 minutes.
# Filename: ../data/raw/rainier_lidar_datasets_dispersed/rainier_west_2002/dtm/rainier_west_2002_dtm_6.tif
# File Size: 329x7608x1
# Pixel Size: 6.000000 x -6.000000
# ...

# %%
ls ../data/processed/rainier_lidar_datasets_dispersed/merged/
# Out:
# dtm_2002.tif                      dtm_2007_in_meters.tif
# dtm_2007.tif                      dtm_2009.tif
# dtm_2007.tif.aux.xml              dtm_2011.tif
# dtm_2007_downsampled.tif          dtm_2012.tif
# dtm_2007_downsampled.tif.aux.xml

# %%
ls ../data/processed/wa_state_lidar_datasets/merged/
# Out:
# dtm.tif
# dtm_clipped_to_07_1m_lidar_dem.tif
# dtm_cropped_to_2007.tif
# dtm_dtm_2007_diff.tif
# dtm_dtm_2007_diff.tif.aux.xml
# dtm_dtm_2007_in_meters_diff.tif
# dtm_dtm_2007_in_meters_diff.tif.aux.xml
